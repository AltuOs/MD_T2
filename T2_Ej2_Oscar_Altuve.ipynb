// %% [markdown]
// # LA-ConGA Physics 2022
//
// # Módulo de Datos
//
// Estudiante: Oscar, Altuve Pabón
//
// Mattermost: @altuos
// ### Tarea 2. Ejercicio 2.

// %% [markdown]
// Reproducir el “análisis de juguete” de una muestra producida a partir de una PDF Gaussiana, descrito en las láminas 55-57.

// %%
#include<TFile.h>
#include<TH1.h>
#include<TMath.h>
#include<math.h>
#include<TF1.h>
#include<TLine.h>
#include<TPoint.h>
#include<iostream>
#include<string>
#include<stdio.h>

// %%
TCanvas c1("c2","c2",10,10,900,600);
c1.SetGrid();

// %%
TF1 mygaus("mygaus","TMath::Gaus(x,0,1,1)",-5,5);
mygaus.Draw();
c1.Draw();

// %%
TH1F h1("h1","test1",100,-5,5);
h1.FillRandom("mygaus",1000);
h1.Draw();
c1.Draw();
